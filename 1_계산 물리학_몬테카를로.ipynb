# %%
import random

rd_num = random.uniform(0,2)

print(rd_num)
# Out:
# 1.8425268029523287

# %%
def g(x):
  return 3 * x**2

# %%
N = 100000
sum = 0

for i in range(N):
  rd_num = random.uniform(0,2)
  sum += g(rd_num)

E = (1/N) * sum # E[g(x)]

print(E)
# Out:
# 3.999144873963455
